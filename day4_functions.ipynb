# %%
def greet():
    print("Welcome To AI in Medicine")
greet()
# Out:
# Welcome To AI in Medicine

# %%
def greet_name(name):
    print("Hello", name)
greet_name("Ifeanyi")
# Out:
# Hello Ifeanyi

# %%
def add_numbers(a, b):
    result = a+b
    print(result)
add_numbers(5,10)
# Out:
# 15

# %%
def calculate_bmi(weight, height):
    bmi = weight/(height**2)
    print(bmi)
calculate_bmi(70, 1.81)
# Out:
# 21.36686914318855

# %%
def bmi_category(bmi):
    if bmi <18.5:
        print("underweight")
    elif bmi<25:
        print("normal weight")
    elif bmi<30:
        print("overweight")
    else:
        print("obesity")
bmi_category(22)
# Out:
# normal weight

# %%
def bmi_category(bmi):
    if bmi <18.5:
        print("underweight")
    elif bmi<25:
        print("normal weight")
    elif bmi<30:
        print("overweight")
    else:
        print("obesity")
bmi_category(17)
# Out:
# underweight

# %%
def bmi_category(bmi):
    if bmi <18.5:
        print("underweight")
    elif bmi<25:
        print("normal weight")
    elif bmi<30:
        print("overweight")
    else:
        print("obesity")
bmi_category(28)
# Out:
# overweight

# %%
def bmi_category(bmi):
    if bmi <18.5:
        print("underweight")
    elif bmi<25:
        print("normal weight")
    elif bmi<30:
        print("overweight")
    else:
        print("obesity")
bmi_category(33)
# Out:
# obesity

# %%
def calculate_bmi(weight, height):
    bmi = weight/(height**2)
    return bmi
my_bmi = calculate_bmi(70, 1.81)
print(my_bmi)
calculate_bmi(70, 1.81)
def bmi_category(bmi):
    if bmi<18.5:
        print("underweight")
    elif bmi<25:
        print("normal weight")
    elif bmi<30:
        print("overweight")
    else:
        print("obese")
bmi_category(21)
# Out:
# 21.36686914318855
# normal weight

# %%
def calculate_bmi(weight, height):
    calculate_bmi = weight/(height**2)
    return bmi
    my_bmi = calculate_bmi(70, 1.75)
    print(my_bmi)
    bmi_category(my_bmi)

# %%
def check_temperature(temp):
    if temp>38:
        print("fever")
    else:
        print("normal")
check_temperature(38)
# Out:
# normal
