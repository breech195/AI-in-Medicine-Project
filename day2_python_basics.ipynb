# %%
age = 30
height = 1.8
name = "Ifeanyi"
is_doctor = True

print(age)
print(height)
print(name)
print(is_doctor)
# Out:
# 30
# 1.8
# Ifeanyi
# True

# %%
patients = ["John","Ali","Ngozi", "Mary"]
print(patients)
print(patients[0])
print(patients[2])
# Out:
# ['John', 'Ali', 'Ngozi', 'Mary']
# John
# Ngozi

# %%
patients.append("David")
print(patients)
# Out:
# ['John', 'Ali', 'Ngozi', 'Mary', 'David', 'David']

# %%
a = 10
b = 5
print(a-b)
print(a+b)
print(a/b)
print(a*b)
# Out:
# 5
# 15
# 2.0
# 50

# %%
day1 = 12
day2 = 15
day3 = 10
total = day1+day2+day3
print(total)
# Out:
# 37

# %%
average = (total/3)
print(average)
# Out:
# 12.333333333333334

# %%
diseases = ["Malaria","Diabetes","Measles","Cancer","Lassa"]
print(diseases)
print(diseases[4])
# Out:
# ['Malaria', 'Diabetes', 'Measles', 'Cancer', 'Lassa']
# Lassa

# %%
diseases.append("Urticaria")
print(diseases)
# Out:
# ['Malaria', 'Diabetes', 'Measles', 'Cancer', 'Lassa', 'Urticaria']
