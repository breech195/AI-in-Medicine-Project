# %%
print("Hello Doctor AI")
# Out:
# Hello Doctor AI

# %%
2+2
# Out:
# 4

# %%
name = "ifeanyi"

# %%
age = 30

# %%
patients_seen = 15

# %%
print(name)
# Out:
# ifeanyi

# %%
print(age)
# Out:
# 30

# %%
print(patients_seen)
# Out:
# 15

# %%
diseases = ["Hypertension", "Diabetes", "Malaria"]
print(diseases)
# Out:
# ['Hypertension', 'Diabetes', 'Malaria']
